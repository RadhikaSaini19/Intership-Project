# %%
import torch
import torch.nn as nn
import torchvision
import torch.backends.cudnn as cudnn
import torch.optim
import os
import sys
import argparse
import time
import dataloader
import model
import numpy as np
from torchvision import transforms
from PIL import Image
import glob
import time
from IPython.display import display
from IPython.display import Image as IMG

# %%
def lowlight(image_path):
    os.environ['CUDA_VISIBLE_DEVICES']='0'
    data_lowlight = Image.open(image_path)

 

    data_lowlight = (np.asarray(data_lowlight)/255.0)


    data_lowlight = torch.from_numpy(data_lowlight).float()
    data_lowlight = data_lowlight.permute(2,0,1)
    data_lowlight = data_lowlight.cuda().unsqueeze(0)

    DCE_net = model.enhance_net_nopool().cuda()
    DCE_net.load_state_dict(torch.load('snapshots/Epoch199.pth'))
    start = time.time()
    _,enhanced_image,_ = DCE_net(data_lowlight)

    end_time = (time.time() - start)
    print(end_time)
    image_path = image_path.replace('test_data','result')
    result_path = image_path
    if not os.path.exists(image_path.replace('/'+image_path.split("/")[-1],'')):
        os.makedirs(image_path.replace('/'+image_path.split("/")[-1],''))

    torchvision.utils.save_image(enhanced_image, result_path)

# %%
if __name__ == '__main__':
# test_images
    with torch.no_grad():
        filePath = 'data/test_data/'
        # filePath = 'data/LOL/our485/low/'
    
        file_list = os.listdir(filePath)

        for file_name in file_list:
            test_list = glob.glob(filePath+file_name+"/*") 
            for image in test_list:
                # image = image
                print(image)
                lowlight(image)
# Out:
# data/test_data/trainLow/729.png
# 18.80436372756958
# data/test_data/trainLow/664.png
# 0.0009975433349609375
# data/test_data/trainLow/734.png
# 0.0012929439544677734
# data/test_data/trainLow/213.png
# 0.0010998249053955078
# data/test_data/trainLow/119.png
# 0.000980377197265625
# data/test_data/trainLow/38.png
# 0.000942230224609375
# data/test_data/trainLow/135.png
# 0.0009608268737792969
# data/test_data/trainLow/628.png
# 0.0011491775512695312
# data/test_data/trainLow/596.png
# 0.00125885009765625
# data/test_data/trainLow/198.png
# 0.0009100437164306641
# data/test_data/trainLow/741.png
# 0.0010175704956054688
# data/test_data/trainLow/258.png
# 0.0009496212005615234
# data/test_data/trainLow/330.png
# 0.0009560585021972656
# data/test_data/trainLow/693.png
# 0.00095367431640625
# data/test_data/trainLow/236.png
# 0.00113677978515625
# data/test_data/trainLow/691.png
# 0.0008213520050048828
# data/test_data/trainLow/92.png
# 0.0009005069732666016
# ...

# %%
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/LOL/eval15/low/23.png'))
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/result/testLow/23.png'))

# %%
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/LOL/eval15/low/493.png'))
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/result/testLow/493.png'))

# %%
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/LOL/eval15/low/778.png'))
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/result/testLow/778.png'))

# %%
def lowlight(image_path):
    os.environ['CUDA_VISIBLE_DEVICES']='0'
    data_lowlight = Image.open(image_path)

 

    data_lowlight = (np.asarray(data_lowlight)/255.0)


    data_lowlight = torch.from_numpy(data_lowlight).float()
    data_lowlight = data_lowlight.permute(2,0,1)
    data_lowlight = data_lowlight.cuda().unsqueeze(0)

    DCE_net = model.enhance_net_nopool().cuda()
    DCE_net.load_state_dict(torch.load('snapshots/Epoch199.pth'))
    start = time.time()
    _,enhanced_image,_ = DCE_net(data_lowlight)

    end_time = (time.time() - start)
    print(end_time)
    image_path = image_path.replace('my_data','my_result')
    result_path = image_path
    if not os.path.exists(image_path.replace('/'+image_path.split("/")[-1],'')):
        os.makedirs(image_path.replace('/'+image_path.split("/")[-1],''))

    torchvision.utils.save_image(enhanced_image, result_path)

# %%
if __name__ == '__main__':
# test_images
    with torch.no_grad():
        filePath = 'data/my_data/'
        # filePath = 'data/LOL/our485/low/'
    
        file_list = os.listdir(filePath)

        for file_name in file_list:
            # test_list = glob.glob(filePath+file_name+"/*") 
            # for image in test_list:
                # image = image
            print(os.path.join(filePath,file_name))
            lowlight(os.path.join(filePath,file_name))
# Out:
# data/my_data/my2.jpeg
# 0.007841348648071289
# data/my_data/my4.jpeg
# 0.004853963851928711
# data/my_data/my3.jpeg
# 0.0009210109710693359
# data/my_data/my1.jpeg
# 0.0048274993896484375

# %%
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/my_data/my2.jpeg'))
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/my_result/my2.jpeg'))

# %%
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/my_data/my1.jpeg'))
display(IMG(filename='/home/radhika/WORK/CODE/Zero-DCE/Zero-DCE_code/data/my_result/my1.jpeg'))
